# %% [markdown]
# # Problem A: Recover Young's modulus in 1D Elastostatics
# Consider a rod made of linearly elastic material subjected to some load. Static problems will be considered here, by which is meant it is not necessary to know how the load was applied, or how the material particles moved to reach the stressed state; it is necessary only that the load is applied slowly enough so that the accelerations are zero, or that it was applied sufficiently long ago that any vibrations have died away and movement has ceased.
#
# The equation governing the static response of the rod is:
# $$
# -\frac{d}{dx} \left( k(x) \frac{du}{dx} \right) = f, \quad x \in (0, L) \tag{1}
# $$
# where
# - $u(x):$ displacement field of the rod
# - $k(x):$ Young’s modulus
# - $f=9.81:$ body force per unit length (e.g., gravity)
# - $L=1.:$ Length of the rod
#
# We consider the fixation of both sides of the rod, which leads to the following boundary conditions:
# - $u(0) = u(L) = 0$
#
# ## Task: Recover the Young's modulus $k(x)$ from the observation of displacement field $u(x)$
# In this task, the Young's modulus $k(x)>0$ of the rod is unknown. However, we observe the displacement field $u_{obs}$ (contaminated by noise with noise level $\sim 5\%$) on a set of randomly placed sensors $x_{obs}$ (with size $N_{obs}=500$).
#
# ### The goals
# - Please select a suitable deep learning method for solving this inverse problem to recover the Young's modulus $k(x)$, and explain the reason for using it
# - Report your setups for the implementation, such as network structure, activation function, optimizer (with learning rate), epoch (with batch size), loss weights, and other tricks that are used for improvement.
# - Compute the $L^2$ relative error (on testing dataset) at each training epoch and plot the ```Error vs. epoch``` curve (and report the final error). The $L^2$ relative error between the prediction $k_{pred} (or\ u_{pred})$ and the truth $k_{true} (or\ u_{true})$ is defined as follows:
#   $$error = \sqrt{\frac{\sum^{n}_i|k_{pred}(x_i)-k_{true}(x_i)|^2}{\sum^{n}_{i}|k_{true}(x_i)|^2}}$$
# - Plot the predicted solution (and the ground truth reference) and the pointwise absolute error using separate figures with ```matplotlib```.
#
# ### Dataset
# The observation and the ground truth references are given in the dataset ```ProblemA_dataset.h5```:
# - ```x_obs```: the observation sensors
# - ```u_obs```: the observed displacement field $u$ (contaminated by noise)
# - ```x_test```: the locations where the ground truth is evaluated (Used for computing error and should **not** be used for training)
# - ```k_test```: the ground truth reference for Young's modulus (Used for computing error and should **not** be used for training)
# - ```u_test```: the ground truth reference for displacement field (Used for computing error and should **not** be used for training)
# - Link to dataset: [https://www.kaggle.com/datasets/yhzang32/dno4pdes](https://www.kaggle.com/datasets/yhzang32/dno4pdes)

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
#
with h5py.File('ProblemA_dataset.h5', 'r') as file:
    print(file.keys())
    #
    x_obs = np.array(file['x_obs']).reshape(-1,1)
    u_obs = np.array(file['u_obs']).reshape(-1,1)
    x_test = np.array(file['x_test']).reshape(-1,1)
    k_test = np.array(file['k_test']).reshape(-1,1)
    u_test = np.array(file['u_test']).reshape(-1,1)
#
plt.figure()
plt.scatter(x_obs, u_obs, label='u_obs')
plt.plot(x_test, u_test,color='red', label="u_test")
plt.title('The observation and truth')
plt.legend()
plt.show()
# Out:
# <KeysViewHDF5 ['k_test', 'u_obs', 'u_test', 'x_obs', 'x_test']>

# %%
#print(x_obs) # input for my NN (500,1)
print(x_obs.shape)
#print(u_obs) # output of my NN (500,1)
print(u_obs.shape)
print(x_test.shape)
print(k_test.shape)
print(u_test.shape)
L = 1.0
f = 9.81
# Out:
# (500, 1)
# (500, 1)
# (10001, 1)
# (10001, 1)
# (10001, 1)

# %%
x_obs = torch.tensor(x_obs, dtype=torch.float32).view(-1,1)
u_obs = torch.tensor(u_obs, dtype=torch.float32).view(-1,1)
x_test = torch.tensor(x_test, dtype=torch.float32).view(-1,1)
u_test = torch.tensor(u_test, dtype=torch.float32).view(-1,1)
k_test = torch.tensor(k_test, dtype=torch.float32).view(-1,1)
print(k_test)
print(u_test)
print(x_test)
print(x_obs.shape)
print(u_obs.shape)
print(x_test.shape)
print(k_test.shape)
print(u_test.shape)

x_bd = torch.tensor([[0.0],[1.0]], dtype=torch.float32)
u_bd = torch.tensor([[0.0],[0.0]], dtype=torch.float32)
f=9.18
L=1.0
# Out:
# tensor([[1.0000],
#         [1.0000],
#         [1.0000],
#         ...,
#         [1.0000],
#         [1.0000],
#         [1.0000]])
# tensor([[0.0000],
#         [0.0005],
#         [0.0010],
#         ...,
#         [0.0010],
#         [0.0005],
#         [0.0000]])
# tensor([[0.0000e+00],
#         [1.0000e-04],
#         [2.0000e-04],
#         ...,
#         [9.9980e-01],
#         [9.9990e-01],
#         [1.0000e+00]])
# torch.Size([500, 1])
# torch.Size([500, 1])
# torch.Size([10001, 1])
# torch.Size([10001, 1])
# torch.Size([10001, 1])

# %%
pip install torch-summary
# Out:
# Requirement already satisfied: torch-summary in c:\users\soura\anaconda3\envs\pinns_poisson_solver\lib\site-packages (1.4.5)Note: you may need to restart the kernel to use updated packages.

# %%
import torch 
import torch.nn as nn
import torch.optim as optim
from torchsummary import summary
from torch.autograd import grad, Variable
from torch.utils.data import Dataset, DataLoader
from tqdm import trange
device = ("cuda" if torch.cuda.is_available() else "cpu")
print(device)
class RecoverYoungPINN(nn.Module):
    def __init__(self):
        super(RecoverYoungPINN, self).__init__()

        self.network = nn.Sequential(
            nn.Linear(1,64),
            nn.Tanh(),
            nn.Linear(64,64),
            nn.Tanh(),
            nn.Linear(64,64),
            nn.Tanh(),
            nn.Linear(64,2))

    def forward(self,x):
        output = self.network(x)
        u = output[:,0:1]
        k = output[:,1:2]

        k = torch.nn.functional.softplus(k)

        return u,k

reverse_model = RecoverYoungPINN().to(device)
summary(reverse_model, device=device)
# Out:
# cuda
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─Linear: 2-1                       128
# |    └─Tanh: 2-2                         --
# |    └─Linear: 2-3                       4,160
# |    └─Tanh: 2-4                         --
# |    └─Linear: 2-5                       4,160
# |    └─Tanh: 2-6                         --
# |    └─Linear: 2-7                       130
# =================================================================
# Total params: 8,578
# Trainable params: 8,578
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─Linear: 2-1                       128
# |    └─Tanh: 2-2                         --
# |    └─Linear: 2-3                       4,160
# |    └─Tanh: 2-4                         --
# |    └─Linear: 2-5                       4,160
# |    └─Tanh: 2-6                         --
# |    └─Linear: 2-7                       130
# =================================================================
# Total params: 8,578
# Trainable params: 8,578
# Non-trainable params: 0
# =================================================================

# %%
class LossClass(object):
    def __init__(self, model):
        self.device = device
        self.model = model
        self.getLoss = nn.MSELoss()
        
    def loss_data(self,x_obs,u_obs):
        x_obs=x_obs.to(self.device)
        u_obs=u_obs.to(self.device)

        u_pred,_ = self.model(x_obs)
        loss = self.getLoss(u_pred, u_obs)
        return loss

    def loss_bd(self, x_bd, u_bd):
        x_bd = x_bd.to(self.device)
        u, _ = self.model(x_bd)
        loss = self.getLoss(u,u_bd.to(self.device))
        return loss

    def loss_pde(self, x_in):
        x = Variable(x_in, requires_grad=True).to(self.device)
        u,k = self.model(x)
        du_dx = grad(inputs=x, outputs=u, grad_outputs=torch.ones_like(u),create_graph=True)[0]
        s = k*du_dx
        ds_dx = grad(inputs=x, outputs=s, grad_outputs=torch.ones_like(s),create_graph=True)[0]
        residual = -ds_dx -f
        loss = self.getLoss(residual, torch.zeros_like(residual))
        return loss

    def get_error(self, x_test,u_test,k_test):
        x_test = x_test.to(self.device)
        u_pred, k_pred = self.model(x_test)
        u_numi = torch.sum((u_pred-u_test.to(self.device))**2)
        u_domi = torch.sum(u_test.to(self.device)**2)
        k_numi = torch.sum((k_pred-k_test.to(self.device))**2)
        k_domi = torch.sum(k_test.to(self.device)**2)
        u_error = torch.sqrt(u_numi/u_domi)
        k_error = torch.sqrt(k_numi/k_domi)

        return u_error, k_error

# %%
class MyDataset(Dataset):
    def __init__(self,x):
        self.x=x
    def __getitem__(self,index):
        return self.x[index]
    def __len__(self):
        return self.x.shape[0]

# %%
#parametrrs
x_in = torch.linspace(0.0,1.0,5000).view(-1,1)
dataloader = DataLoader(MyDataset(x_in), batch_size=100, shuffle=True)
epochs =3000
lr=0.001
optimizer = torch.optim.Adam(params=reverse_model.parameters(), lr=lr, weight_decay=1e-4)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=int(epochs/5),gamma=0.5)
scheduler = torch.optim.lr_schedular.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=100)
w_data=100
w_bd=100.0
w_pde= 2.0
u_error_list=[]
k_error_list=[]

# %%
print("Starting training..")
for epochs in trange(epochs):
    for x_batch in dataloader:
        lossClass = LossClass(reverse_model)
        data_loss = lossClass.loss_data(x_obs,u_obs)
        boundary_loss = lossClass.loss_bd(x_bd, u_bd)
        pde_loss = lossClass.loss_pde(x_batch)

        total_loss = w_data*data_loss + w_bd*boundary_loss + w_pde*pde_loss

        optimizer.zero_grad()
        total_loss.backward()
        optimizer.step()

    with torch.no_grad():
        u_err, k_err = lossClass.get_error(x_test, u_test, k_test)
        k_error_list.append(k_err.item())
        u_error_list.append(u_err.item())

    scheduler.step()

    if (epochs + 1) % 100 ==0 :
        current_lr = scheduler.optimizer.param_groups[0]["lr"]
        print(f"\nEpoch: {epochs+1:4d} | Training Loss: {total_loss.item():.4f} | Displacement L^2 error: {u_err.item():.4f} |Young Modulus L^2 error: {k_err.item():.4f} | LR: {current_lr:.6f}")
# Out:
# Starting training..
#   3%|███                                                                                         | 100/3000 [01:23<48:23,  1.00s/it]
# Epoch:  100 | Training Loss: 0.0969 | Displacement L^2 error: 0.0107 |Young Modulus L^2 error: 0.2000 | LR: 0.001000
#   7%|██████▏                                                                                     | 200/3000 [02:54<46:29,  1.00it/s]
# Epoch:  200 | Training Loss: 0.0912 | Displacement L^2 error: 0.0097 |Young Modulus L^2 error: 0.2053 | LR: 0.001000
#  10%|█████████▏                                                                                  | 300/3000 [04:46<53:38,  1.19s/it]
# Epoch:  300 | Training Loss: 0.0911 | Displacement L^2 error: 0.0094 |Young Modulus L^2 error: 0.2008 | LR: 0.001000
#  13%|████████████▎                                                                               | 400/3000 [06:47<52:13,  1.21s/it]
# Epoch:  400 | Training Loss: 0.1100 | Displacement L^2 error: 0.0157 |Young Modulus L^2 error: 0.1998 | LR: 0.001000
#  17%|███████████████▎                                                                            | 500/3000 [08:21<31:34,  1.32it/s]
# Epoch:  500 | Training Loss: 0.0957 | Displacement L^2 error: 0.0091 |Young Modulus L^2 error: 0.1970 | LR: 0.001000
#  20%|██████████████████▍                                                                         | 600/3000 [10:13<55:21,  1.38s/it]
# Epoch:  600 | Training Loss: 0.1383 | Displacement L^2 error: 0.0156 |Young Modulus L^2 error: 0.1935 | LR: 0.000500
#  23%|█████████████████████▍                                                                      | 700/3000 [13:05<54:51,  1.43s/it]
# Epoch:  700 | Training Loss: 0.0906 | Displacement L^2 error: 0.0085 |Young Modulus L^2 error: 0.1871 | LR: 0.000500
#  27%|████████████████████████▌                                                                   | 800/3000 [15:12<28:21,  1.29it/s]
# Epoch:  800 | Training Loss: 0.0901 | Displacement L^2 error: 0.0084 |Young Modulus L^2 error: 0.1832 | LR: 0.000500
#  30%|███████████████████████████▌                                                                | 900/3000 [16:26<25:10,  1.39it/s]
# Epoch:  900 | Training Loss: 0.0903 | Displacement L^2 error: 0.0081 |Young Modulus L^2 error: 0.1806 | LR: 0.000500
#  33%|██████████████████████████████▎                                                            | 1000/3000 [18:02<40:08,  1.20s/it]
# Epoch: 1000 | Training Loss: 0.0914 | Displacement L^2 error: 0.0081 |Young Modulus L^2 error: 0.1778 | LR: 0.000500
#  37%|█████████████████████████████████▎                                                         | 1100/3000 [19:57<37:40,  1.19s/it]
# Epoch: 1100 | Training Loss: 0.0901 | Displacement L^2 error: 0.0079 |Young Modulus L^2 error: 0.1760 | LR: 0.000500
#  40%|████████████████████████████████████▍                                                      | 1200/3000 [21:56<35:00,  1.17s/it]
# Epoch: 1200 | Training Loss: 0.0908 | Displacement L^2 error: 0.0081 |Young Modulus L^2 error: 0.1735 | LR: 0.000250
#  43%|███████████████████████████████████████▍                                                   | 1300/3000 [23:17<19:43,  1.44it/s]
# Epoch: 1300 | Training Loss: 0.0891 | Displacement L^2 error: 0.0075 |Young Modulus L^2 error: 0.1692 | LR: 0.000250
#  47%|██████████████████████████████████████████▍                                                | 1400/3000 [24:41<22:53,  1.16it/s]
# Epoch: 1400 | Training Loss: 0.0897 | Displacement L^2 error: 0.0071 |Young Modulus L^2 error: 0.1659 | LR: 0.000250
#  50%|█████████████████████████████████████████████▌                                             | 1500/3000 [26:30<27:47,  1.11s/it]
# Epoch: 1500 | Training Loss: 0.0889 | Displacement L^2 error: 0.0070 |Young Modulus L^2 error: 0.1628 | LR: 0.000250
#  53%|████████████████████████████████████████████████▌                                          | 1600/3000 [28:34<28:00,  1.20s/it]
# Epoch: 1600 | Training Loss: 0.0888 | Displacement L^2 error: 0.0068 |Young Modulus L^2 error: 0.1599 | LR: 0.000250
#  57%|███████████████████████████████████████████████████▌                                       | 1700/3000 [30:04<15:34,  1.39it/s]
# Epoch: 1700 | Training Loss: 0.0885 | Displacement L^2 error: 0.0067 |Young Modulus L^2 error: 0.1574 | LR: 0.000250
#  60%|██████████████████████████████████████████████████████▌                                    | 1800/3000 [31:18<14:07,  1.42it/s]
# Epoch: 1800 | Training Loss: 0.0887 | Displacement L^2 error: 0.0065 |Young Modulus L^2 error: 0.1545 | LR: 0.000125
#  63%|█████████████████████████████████████████████████████████▋                                 | 1900/3000 [32:57<20:11,  1.10s/it]
# Epoch: 1900 | Training Loss: 0.0883 | Displacement L^2 error: 0.0063 |Young Modulus L^2 error: 0.1513 | LR: 0.000125
#  67%|████████████████████████████████████████████████████████████▋                              | 2000/3000 [34:48<17:52,  1.07s/it]
# Epoch: 2000 | Training Loss: 0.0881 | Displacement L^2 error: 0.0062 |Young Modulus L^2 error: 0.1484 | LR: 0.000125
#  70%|███████████████████████████████████████████████████████████████▋                           | 2100/3000 [36:41<10:39,  1.41it/s]
# Epoch: 2100 | Training Loss: 0.0882 | Displacement L^2 error: 0.0059 |Young Modulus L^2 error: 0.1458 | LR: 0.000125
#  73%|██████████████████████████████████████████████████████████████████▋                        | 2200/3000 [37:53<10:02,  1.33it/s]
# Epoch: 2200 | Training Loss: 0.0880 | Displacement L^2 error: 0.0058 |Young Modulus L^2 error: 0.1434 | LR: 0.000125
#  77%|█████████████████████████████████████████████████████████████████████▊                     | 2300/3000 [39:28<10:01,  1.16it/s]
# Epoch: 2300 | Training Loss: 0.0878 | Displacement L^2 error: 0.0057 |Young Modulus L^2 error: 0.1410 | LR: 0.000125
#  80%|████████████████████████████████████████████████████████████████████████▊                  | 2400/3000 [40:53<08:42,  1.15it/s]
# Epoch: 2400 | Training Loss: 0.0877 | Displacement L^2 error: 0.0058 |Young Modulus L^2 error: 0.1388 | LR: 0.000063
#  83%|███████████████████████████████████████████████████████████████████████████▊               | 2500/3000 [42:36<08:57,  1.08s/it]
# Epoch: 2500 | Training Loss: 0.0876 | Displacement L^2 error: 0.0056 |Young Modulus L^2 error: 0.1367 | LR: 0.000063
#  87%|██████████████████████████████████████████████████████████████████████████████▊            | 2600/3000 [44:33<08:13,  1.23s/it]
# Epoch: 2600 | Training Loss: 0.0876 | Displacement L^2 error: 0.0055 |Young Modulus L^2 error: 0.1346 | LR: 0.000063
#  90%|█████████████████████████████████████████████████████████████████████████████████▉         | 2700/3000 [46:08<04:15,  1.17it/s]
# Epoch: 2700 | Training Loss: 0.0877 | Displacement L^2 error: 0.0053 |Young Modulus L^2 error: 0.1325 | LR: 0.000063
#  93%|████████████████████████████████████████████████████████████████████████████████████▉      | 2800/3000 [47:26<02:53,  1.15it/s]
# Epoch: 2800 | Training Loss: 0.0874 | Displacement L^2 error: 0.0052 |Young Modulus L^2 error: 0.1306 | LR: 0.000063
#  97%|███████████████████████████████████████████████████████████████████████████████████████▉   | 2900/3000 [48:59<01:37,  1.02it/s]
# Epoch: 2900 | Training Loss: 0.0874 | Displacement L^2 error: 0.0052 |Young Modulus L^2 error: 0.1289 | LR: 0.000063
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 3000/3000 [50:51<00:00,  1.02s/it]
# Epoch: 3000 | Training Loss: 0.0874 | Displacement L^2 error: 0.0052 |Young Modulus L^2 error: 0.1271 | LR: 0.000031

# %%
def plot_results(x_test, u_test,K_test, reverse_model):
    reverse_model.eval()
    with torch.no_grad():
        u_pred, k_pred = reverse_model(x_test.to(device))
        x = x_test.cpu().numpy()
        u_true = u_test.cpu().numpy()
        k_true = k_test.cpu().numpy()

        u_pred = u_pred.cpu().numpy()
        k_pred = k_pred.cpu().numpy()

    u_abs_error = np.abs(u_pred-u_true)
    k_abs_error = np.abs(k_pred-k_true)

    fig, (ax1,ax2,ax3,ax4) = plt.subplots(1,4, figsize=(14,5))

    ax1.plot(x,u_true, 'k--', label="True Displacement (u_test)", linewidth=2)
    ax1.plot(x,u_pred, 'r-', label="PINN Prediction")
    ax1.set_title("Displacement profile")
    ax1.set_xlabel("x")
    ax1.set_ylabel("displacement")
    ax1.legend()
    ax1.grid(True)

    ax2.plot(x,k_true, 'k--', label="True Youngs modulus (k_test)", linewidth=2)
    ax2.plot(x,k_pred, 'r-', label="PINN Prediction")
    ax2.set_title("Young modulus profile")
    ax2.set_xlabel("x")
    ax2.set_ylabel("young modulus")
    ax2.legend()
    ax2.grid(True)

    ax3.plot(x,u_abs_error, 'm-', label="Displacement Absolute error", linewidth=2)
  
    ax3.set_title("Displacement profile absolute error")
    ax3.set_xlabel("x")
    ax3.set_ylabel("Absolute Error")
    ax3.legend()
    ax3.grid(True)

    ax4.plot(x,k_abs_error, 'g-', label="Young Modulus Absolute error", linewidth=2)
    ax4.set_title("Young modulus profile Absolute error")
    ax4.set_xlabel("x")
    ax4.set_ylabel("Absolute Error")
    ax4.legend()
    ax4.grid(True)

    plt.tight_layout()
    plt.show()

plot_results(x_test,u_test,k_test, reverse_model)
